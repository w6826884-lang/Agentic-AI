# %%
import openai
from phi.agent import Agent
import phi.api
from phi.model.openai import OpenAIChat
from phi.tools.yfinance import YFinanceTools
from phi.tools.duckduckgo import DuckDuckGo
from dotenv import load_dotenv
from phi.model.groq import Groq

import os
import phi
from phi.playground import Playground, serve_playground_app

# Load environment variables from .env file
load_dotenv()

phi.api = os.getenv("phi-m-wCYikmB_PuwJKoHhLCX7B7BuE4Yx9BOWXb_Ff8gAE")

# %%
## web search agent
web_search_agent = Agent(
    name="Web Search Agent",
    role="Search the web for information",
    model=Groq(id="llama-3.1-8b-instant"),
    tools=[DuckDuckGo()],
    instructions=["Always include sources"],
    show_tool_calls=True,
    markdown=True
)

# %%
finance_agent = Agent(
    name="Finance AI Agent",
    model=Groq(id="llama-3.1-8b-instant"),
    tools=[
        YFinanceTools(
            company_news=True,
            stock_fundamentals=True,
            analyst_recommendations=True,
            stock_price=True
        )
    ],
    instructions=[
        "Use tables to display the data"
    ],
    show_tool_calls=True,
    markdown=True
)

# %%
app = Playground(agents=[finance_agent, web_search_agent]).get_app()

if __name__ == "__main__":
    serve_playground_app("playground:app", reload=True)
# Out:
# INFO     Starting playground on http://localhost:7777
# ┏━━━━━━━━━━━━━━━━━━━━━━━ Agent Playground ━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                 ┃
# ┃                                                                 ┃
# ┃  URL: ]8;id=764769;https://phidata.app/playground?endpoint=localhost%3A7777\https://phidata.app/playground?endpoint=localhost%3A7777]8;;\  ┃
# ┃                                                                 ┃
# ┃                                                                 ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# INFO:     Will watch for changes in these directories: ['c:\\Users\\Spandan Banerjee\\Documents\\Agentic AI']
# INFO:     Uvicorn running on http://localhost:7777 (Press CTRL+C to quit)
# INFO:     Started reloader process [12436] using StatReload
# WARNING:  StatReload detected changes in 'financial_agent.py'. Reloading...
